# %% [markdown]
# <a href="https://colab.research.google.com/github/lasagnanet/ho/blob/main/AppleSel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#自分のドライブをマウントする
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#YOLOv8の必要なライブラリをインストールする
# !pip install ultralytics

# %%
#YOLOv8nで100エポック学習する
# !yolo task=detect mode=train model=yolov8n.pt data='/content/drive/MyDrive/AxrossRecipe/Apple/data.yaml'  epochs=100  project=yolov8_Apple_n
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 366MB/s]
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#testデータを使い学習したモデルで推論する
! yolo predict model=/content/yolov8_Apple_n/train/weights/Apple_best.pt source='/content/drive/MyDrive/AxrossRecipe/Apple/test'
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/5 /content/drive/MyDrive/AxrossRecipe/Apple/test/2_20241220_2_U1_RRH_N--_N.jpg: 384x640 1 No_Honey, 62.4ms
# image 2/5 /content/drive/MyDrive/AxrossRecipe/Apple/test/2_20241220_2_U1_RWH_N--_N.jpg: 384x640 1 No_Honey, 7.4ms
# image 3/5 /content/drive/MyDrive/AxrossRecipe/Apple/test/3_20241220_2_U1_RBGH_N--_M.jpg: 384x640 (no detections), 9.5ms
# image 4/5 /content/drive/MyDrive/AxrossRecipe/Apple/test/test1220-3-2-g.jpg: 384x640 1 Contains_Honey, 6.3ms
# image 5/5 /content/drive/MyDrive/AxrossRecipe/Apple/test/test1220-3-4-w.jpg: 384x640 1 Contains_Honey, 6.3ms
# Speed: 3.5ms preprocess, 18.4ms inference, 193.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
